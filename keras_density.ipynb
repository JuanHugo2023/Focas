# %%
# %load_ext autoreload
# %autoreload 2
# %load_ext line_profiler

# %%
from keras_density import *
from keras.models import load_model
from keras.optimizers import SGD
import matplotlib.pyplot as plt
import matplotlib
# Out:
# Using TensorFlow backend.

# %%
# %matplotlib notebook

# %%
model = build_model()
model.load_weights('keras_density.hdf5')

# using load_model seems preferable to load_weights, because the file also stores the structure of the model,
# but this causes ResourceExhaustionErrors from TensorFlow, for some reason

# model = load_model('keras_density/weights-area_loss-2.00.hdf5', model_objects)

# %%
train_top(model, 64, loss=area_loss, run_name='area_loss-fine-tune', initial_epoch=0, optimizer=RMSprop(lr=0.0001))
# Out:
# density_true.shape (?, ?, ?, ?)
# loss per channel (?, 5)
# loss (?,)
# diff abs (?, 5)
# diff mean (?,)
# steps_per_epoch=2737
# INFO:tensorflow:Summary name block1_conv1/kernel:0 is illegal; using block1_conv1/kernel_0 instead.
# INFO:tensorflow:Summary name block1_conv1_bn/gamma:0 is illegal; using block1_conv1_bn/gamma_0 instead.
# INFO:tensorflow:Summary name block1_conv1_bn/beta:0 is illegal; using block1_conv1_bn/beta_0 instead.
# INFO:tensorflow:Summary name block1_conv1_bn/moving_mean:0 is illegal; using block1_conv1_bn/moving_mean_0 instead.
# INFO:tensorflow:Summary name block1_conv1_bn/moving_variance:0 is illegal; using block1_conv1_bn/moving_variance_0 instead.
# INFO:tensorflow:Summary name block1_conv2/kernel:0 is illegal; using block1_conv2/kernel_0 instead.
# INFO:tensorflow:Summary name block1_conv2_bn/gamma:0 is illegal; using block1_conv2_bn/gamma_0 instead.
# INFO:tensorflow:Summary name block1_conv2_bn/beta:0 is illegal; using block1_conv2_bn/beta_0 instead.
# ...

# %%
model.save('temp.hdf5')

# %%
model.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ...
# input_1 (InputLayer)             (None, 327, 327, 3)   0
# ____________________________________________________________________________________________________
# block1_conv1 (Conv2D)            (None, 163, 163, 32)  864         input_1[0][0]
# ____________________________________________________________________________________________________
# block1_conv1_bn (BatchNormalizat (None, 163, 163, 32)  128         block1_conv1[0][0]
# ____________________________________________________________________________________________________
# block1_conv1_act (Activation)    (None, 163, 163, 32)  0           block1_conv1_bn[0][0]
# ____________________________________________________________________________________________________
# ...

# %% [markdown]
# Examine which layers are frozen, and which are trainable

# %%
for (i,layer) in enumerate(model.layers):
    print(i,layer.name,layer.trainable)
# Out:
# 0 input_1 False
# 1 block1_conv1 False
# 2 block1_conv1_bn False
# 3 block1_conv1_act False
# 4 block1_conv2 False
# 5 block1_conv2_bn False
# 6 block1_conv2_act False
# 7 block2_sepconv1 False
# 8 block2_sepconv1_bn False
# 9 block2_sepconv2_act False
# 10 block2_sepconv2 False
# 11 block2_sepconv2_bn False
# 12 conv2d_1 False
# 13 block2_pool False
# 14 batch_normalization_1 False
# 15 add_1 False
# 16 block3_sepconv1_act False
# 17 block3_sepconv1 False
# 18 block3_sepconv1_bn False
# 19 block3_sepconv2_act False
# 20 block3_sepconv2 False
# 21 block3_sepconv2_bn False
# 22 conv2d_2 False
# 23 block3_pool False
# 24 batch_normalization_2 False
# 25 add_2 False
# 26 block4_sepconv1_act False
# 27 block4_sepconv1 False
# 28 block4_sepconv1_bn False
# 29 block4_sepconv2_act False
# 30 block4_sepconv2 False
# 31 block4_sepconv2_bn False
# 32 conv2d_3 False
# 33 block4_pool False
# 34 batch_normalization_3 False
# 35 add_3 False
# 36 block5_sepconv1_act False
# ...

# %% [markdown]
# I've tried fine tuning lower layers after training to convergance on the top layers. I didn't see any dramatic improvements, but this is how you can unfreeze some lower layers

# %%
for layer in model.layers:
    layer.trainable = layer.name.startswith("block14")
    layer.trainable |= layer.name.startswith("block15")

# %% [markdown]
# An example I saw switched so SGD with a much lower learning rate when fine tuning lower layers, like this

# %%
train_top(model, 64, loss=area_loss, run_name='area_loss-2', initial_epoch=2, optimizer=SGD(lr=0.0001, momentum=0.9))
# Out:
# density_true.shape (?, ?, ?, ?)
# loss per channel (?, 5)
# loss (?,)
# diff abs (?, 5)
# diff mean (?,)
# steps_per_epoch=2737
# INFO:tensorflow:Summary name block1_conv1/kernel:0 is illegal; using block1_conv1/kernel_0 instead.
# INFO:tensorflow:Summary name block1_conv1_bn/gamma:0 is illegal; using block1_conv1_bn/gamma_0 instead.
# INFO:tensorflow:Summary name block1_conv1_bn/beta:0 is illegal; using block1_conv1_bn/beta_0 instead.
# INFO:tensorflow:Summary name block1_conv1_bn/moving_mean:0 is illegal; using block1_conv1_bn/moving_mean_0 instead.
# INFO:tensorflow:Summary name block1_conv1_bn/moving_variance:0 is illegal; using block1_conv1_bn/moving_variance_0 instead.
# INFO:tensorflow:Summary name block1_conv2/kernel:0 is illegal; using block1_conv2/kernel_0 instead.
# INFO:tensorflow:Summary name block1_conv2_bn/gamma:0 is illegal; using block1_conv2_bn/gamma_0 instead.
# INFO:tensorflow:Summary name block1_conv2_bn/beta:0 is illegal; using block1_conv2_bn/beta_0 instead.
# ...

# %% [markdown]
# # Evaluation
# ## All training
# This computes the scores for the training examples in a random order, so you can quickly get some idea of how its doing. It takes an hour or 2 to score all the training examples, however

# %%
training_ids, diff = training_scores(model)
# Out:
# tid:256 (0/891)
# counts_true: [15  0 92 53 59]
# counts_pred: [ 13.2907896    8.61135674  83.4552536   37.33546066  42.61014175]
# diff: [ -1.7092104    8.61135674  -8.5447464  -15.66453934 -16.38985825]
# diff_ratio [ 1.12860112  0.          1.10238716  1.41956197  1.38464688]
# avg_diff_ratio [ 1.12860112  0.          1.10238716  1.41956197  1.38464688]
# diff_sq: [   2.92140018   74.15546482   73.01269102  245.37779265  268.62745332]
# avg_diff_sq: [   2.92140018   74.15546482   73.01269102  245.37779265  268.62745332]
# score: 10.1839422226
# cumm score: 10.1839422226
#
# tid:575 (1/891)
# counts_true: [ 2  1 19  3  0]
# counts_pred: [  2.74466181   2.34036255  16.79530716  12.29005623   2.24778509]
# diff: [ 0.74466181  1.34036255 -2.20469284  9.29005623  2.24778509]
# diff_ratio [ 0.72868723  0.42728423  1.13126838  0.24409978  0.        ]
# avg_diff_ratio [ 0.92864417  0.21364211  1.11682777  0.83183087  0.69232344]
# ...

# %%
import pandas as pd
diff_table = pd.DataFrame(diff, index=training_ids, columns=engine.class_names)
diff_table.index.name = 'train_id'
diff_table = diff_table.sort_index()
diff_table[:10]
# Out:
#           adult_males  subadult_males  adult_females  juveniles       pups
# train_id
# 0          -23.823341       14.097837     -74.260101  54.676353 -52.315948
# 1            2.418530      -14.984588      12.208391  -6.786634   6.085156
# 2           -0.253912        1.493492      -7.735229  -5.259637   1.140245
# 4           -3.157815       -5.722424       6.521199   4.180814   3.067682
# 5           -2.827576       -2.640640       5.502426  -1.687220   2.709553
# 6            0.425651       -3.694525      -0.886990  -9.980771   3.164484
# 8           -2.651255       -1.439605      -0.799805   9.688540  -0.463585
# 10          -3.413634       -3.107060       6.886539   1.401233   3.028126
# 11          -0.682370       -3.627757     -16.071531  -3.379269   4.404582
# 12          -2.209768       -4.550343       3.306629   4.361980   2.318218

# %%
diff_table.to_csv('diff.csv')

# %%
diff_table.mean() / engine.counts.mean()
# Out:
# adult_males       0.145386
# subadult_males   -0.044961
# adult_females     0.245324
# juveniles         0.088295
# pups              0.391556
# dtype: float64

# %%
fractional_error = diff_table / (engine.counts+0.001)
fractional_error[:10]
# Out:
#           adult_males  subadult_males  adult_females    juveniles  \
# train_id
# 0           -0.378937        1.247129      -0.152461     1.307860
# 1            2.227576       -0.572127   20023.918152    -0.356696
# 2           -0.125113     1523.567796      -0.203367    -0.264787
# 4           -0.432829       -0.531710       3.852530  4546.515465
# 5           -0.409696       -0.615330       0.437820    -0.412043
# 6            0.206554       -0.739193      -0.046613    -0.554879
# 8            0.359784        0.412288       1.009480     5.460344
# 10          -0.469870       -0.641936       4.061834     1.829906
# 11          -0.241777       -0.729368      -0.451638    -0.266611
# 12          -0.160840       -0.315538       0.396349     5.842957
#
#                   pups
# train_id
# 0            -0.149627
# 1         10168.266296
# 2          1131.104112
# 4          3774.914265
# 5             0.213192
# 6          3108.422518
# 8             1.110264
# 10         5542.323589
# ...

# %%
np.sqrt(diff_table.var()) / engine.counts.mean()
# Out:
# adult_males       0.875829
# subadult_males    1.319576
# adult_females     0.815671
# juveniles         1.183447
# pups              1.261353
# dtype: float64

# %%
counts_pred = engine.counts + diff_table

# %%
counts_pred.loc[198,:]
# Out:
# adult_males       3.368554
# subadult_males    1.432930
# adult_females     5.043180
# juveniles         2.046582
# pups              3.250715
# Name: 198, dtype: float64

# %%
counts_pred.to_csv('pred.csv')

# %%
np.sqrt((diff_table**2).mean())
# Out:
# adult_males        5.122807
# subadult_males     5.974492
# adult_females     34.261331
# juveniles         25.309559
# pups              23.913564
# dtype: float64

# %%
np.sqrt(((diff_table - diff_table.mean())**2).mean()).mean()
# Out:
# 18.381848213275163

# %%
np.sqrt((diff.mean(axis=1) ** 2).mean())
# Out:
# 12.926107305818952

# %% [markdown]
# ## Single image

# %%
# %timeit predict_large_image(model,engine.training_mmap_image(0))
# Out:
# 1 loop, best of 3: 6.29 s per loop

# %%
# %lprun -f predict_large_image predict_large_image(model,engine.training_mmap_image(0))
# Out:
# UsageError: option -f not recognized ( allowed: "n:r:tcp:qo" )

# %%
# %lprun?

# %%
tid=0
pred=predict_large_image(model,engine.training_mmap_image(tid))
pred_sum = pred.sum(axis=(0,1))
true_sum = engine.counts.loc[tid,engine.class_names].as_matrix()
abs_diff = np.abs(pred_sum-true_sum)
print("pred:", pred_sum)
print("true:", true_sum)
print("diff:", abs_diff)
print("score:", np.mean(abs_diff))
# Out:
# pred: [  38.50551987   26.96680069  411.90402222   96.931427    292.52813721]
# true: [ 62  12 486  42 344]
# diff: [ 23.49448013  14.96680069  74.09597778  54.931427    51.47186279]
# score: 43.7921096802

# %%
pred.dtype
# Out:
# dtype('float32')

# %%
plt.imshow(pred[:,:].sum(axis=2)) # all sea lions
# plt.imshow(pred[:,:,engine.class_by_name['adult_females']] # a single class
plt.colorbar()
# Out:
# <img src="data:image/png;base64,..." width="640">
