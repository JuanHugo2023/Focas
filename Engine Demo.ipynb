# %%
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
# %matplotlib notebook

# %%
from engine import Engine

# %%
engine = Engine()

# %%
density = engine.training_density(0, engine.class_by_name['adult_females'])
img = engine.training_image(0)

# %%
cmap = matplotlib.cm.ScalarMappable(cmap='hot') # matplotlib.cm.get_cmap('viridis')
density_img = cmap.to_rgba(density)
density_img[:,:,3] = density/density.max()
#density_img = np.stack([np.ones(d.shape),np.zeros(d.shape),np.ones(d.shape),d/d.max()], axis=-1)
img_w, img_h = density.shape
extent = 0,img_h,0,img_w
plt.imshow(img, interpolation='bilinear', extent=extent)
plt.imshow(density_img, extent=extent)
# Out:
# <img src="data:image/png;base64,..." width="640">
